# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np 
x = np.array([1, 3, 5, 2, 9])
y = np.array([-1, 3, 15, 27, 29])
print("Number of elements in vector x is: ",x.size)
print("Number of elements in vector y is: ",y.size)
# Out:
# Number of elements in vector x is:  5
# Number of elements in vector y is:  5

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n = (int)(input("Enter the list"))
result =0
b=[12+2*i for i in range (n)]
print(b)
# Out:
# [12, 14, 16]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n = (int)(input("Enter the list"))
result =0
b=[31+2*i for i in range (n)]
print(b)
# Out:
# [31, 33, 35]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x = ()
